# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, header=None, names=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm", "class"])
df.insert(0, "id", range(1, len(df) + 1))
df
# Out:
#       id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sepal_length_column = df["SepalLengthCm"]
sepal_length_column
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df.describe(include='all')
# Out:
#                 id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#               class
# count           150
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#       id           class  SepalWidthCm  SepalLengthCm  PetalWidthCm  \
# 0      1     Iris-setosa           3.5            5.1           0.2
# 1      2     Iris-setosa           3.0            4.9           0.2
# 2      3     Iris-setosa           3.2            4.7           0.2
# 3      4     Iris-setosa           3.1            4.6           0.2
# 4      5     Iris-setosa           3.6            5.0           0.2
# ..   ...             ...           ...            ...           ...
# 145  146  Iris-virginica           3.0            6.7           2.3
# 146  147  Iris-virginica           2.5            6.3           1.9
# 147  148  Iris-virginica           3.0            6.5           2.0
# 148  149  Iris-virginica           3.4            6.2           2.3
# 149  150  Iris-virginica           3.0            5.9           1.8
#
#      PetalLengthCm
# 0              1.4
# 1              1.4
# 2              1.3
# 3              1.5
# 4              1.4
# ..             ...
# ...

# %%
df.iloc[10]
# Out:
# id                        11
# SepalLengthCm            5.4
# SepalWidthCm             3.7
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# class            Iris-setosa
# Name: 10, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
df['class'] = lbl.fit_transform(df['class'])
df.head(100)
# Out:
#      id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  class
# 0     1            5.1           3.5            1.4           0.2      0
# 1     2            4.9           3.0            1.4           0.2      0
# 2     3            4.7           3.2            1.3           0.2      0
# 3     4            4.6           3.1            1.5           0.2      0
# 4     5            5.0           3.6            1.4           0.2      0
# ..  ...            ...           ...            ...           ...    ...
# 95   96            5.7           3.0            4.2           1.2      1
# 96   97            5.7           2.9            4.2           1.3      1
# 97   98            6.2           2.9            4.3           1.3      1
# 98   99            5.1           2.5            3.0           1.1      1
# 99  100            5.7           2.8            4.1           1.3      1
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# class            0
# dtype: int64

# %%
df.corr()
# Out:
#                      id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# class          0.942830       0.782561     -0.419446       0.949043
#
#                PetalWidthCm     class
# id                 0.899759  0.942830
# SepalLengthCm      0.817954  0.782561
# SepalWidthCm      -0.356544 -0.419446
# PetalLengthCm      0.962757  0.949043
# PetalWidthCm       1.000000  0.956464
# class              0.956464  1.000000

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter', x='SepalLengthCm', y='PetalLengthCm', c='teal', s=30)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

class_colors = {
    'Iris-setosa': 'blue',
    'Iris-versicolor': 'orange',
    'Iris-virginica': 'green'
}
g = sns.FacetGrid(df, hue="class", height=6)
g.map(plt.scatter, 'SepalLengthCm', 'PetalLengthCm')

legend_labels = []
for class_name, color in class_colors.items():
    plt.scatter([], [], label=class_name, color=color)
    legend_labels.append(class_name)
    
g.add_legend(labels=legend_labels, title="Classes")

plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:181: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %%
x = df[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]].values
y = df[["class"]].values

# %%
#TRAINING

# %%
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
#TESTING

# %%
x_predict = lr.predict(x_test)
x_predict
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
lr.score(x_test, y_test)
# Out:
# 1.0

# %%
from sklearn import metrics
Actual = y
predicted = lr.predict(x)
print(metrics.classification_report(Actual, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      0.94      0.97        50
#            2       0.94      1.00      0.97        50
#
#     accuracy                           0.98       150
#    macro avg       0.98      0.98      0.98       150
# weighted avg       0.98      0.98      0.98       150

# %%
sns.pairplot(df)
